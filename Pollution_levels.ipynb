# %%
import pandas as pd 
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt 
print('Modules are imported.')
# Out:
# Modules are imported.

# %%
city_day= pd.read_csv('city_day.csv')

# %%
display("CITY DAILY DATA")
display(city_day.head(5))
# Out:
# 'CITY DAILY DATA'
#         City        Date  PM2.5  PM10     NO    NO2    NOx  NH3     CO    SO2  \
# 0  Ahmedabad  2015-01-01    NaN   NaN   0.92  18.22  17.15  NaN   0.92  27.64
# 1  Ahmedabad  2015-01-02    NaN   NaN   0.97  15.69  16.46  NaN   0.97  24.55
# 2  Ahmedabad  2015-01-03    NaN   NaN  17.40  19.30  29.70  NaN  17.40  29.07
# 3  Ahmedabad  2015-01-04    NaN   NaN   1.70  18.48  17.97  NaN   1.70  18.59
# 4  Ahmedabad  2015-01-05    NaN   NaN  22.10  21.42  37.76  NaN  22.10  39.33
#
#        O3  Benzene  Toluene  Xylene  AQI AQI_Bucket
# 0  133.36     0.00     0.02    0.00  NaN        NaN
# 1   34.06     3.68     5.50    3.77  NaN        NaN
# 2   30.70     6.80    16.40    2.25  NaN        NaN
# 3   36.08     4.43    10.14    1.00  NaN        NaN
# 4   39.31     7.01    18.89    2.78  NaN        NaN

# %%
city_day.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29531 entries, 0 to 29530
# Data columns (total 16 columns):
# City          29531 non-null object
# Date          29531 non-null object
# PM2.5         24933 non-null float64
# PM10          18391 non-null float64
# NO            25949 non-null float64
# NO2           25946 non-null float64
# NOx           25346 non-null float64
# NH3           19203 non-null float64
# CO            27472 non-null float64
# SO2           25677 non-null float64
# O3            25509 non-null float64
# Benzene       23908 non-null float64
# Toluene       21490 non-null float64
# Xylene        11422 non-null float64
# AQI           24850 non-null float64
# AQI_Bucket    24850 non-null object
# dtypes: float64(13), object(3)
# memory usage: 3.6+ MB

# %%
def missing_values_table(df):
        mis_val = df.isnull().sum()
        mis_val_percent = 100 * df.isnull().sum() / len(df)
        mis_val_table = pd.concat([mis_val, mis_val_percent], axis=1)
        mis_val_table_ren_columns = mis_val_table.rename(
        columns = {0 : 'Missing Values', 1 : '% of Total Values'})

        mis_val_table_ren_columns = mis_val_table_ren_columns[
            mis_val_table_ren_columns.iloc[:,1] != 0].sort_values(
        '% of Total Values', ascending=False).round(1)
        print ("Your selected dataframe has " + str(df.shape[1]) + " columns.\n"      
            "There are " + str(mis_val_table_ren_columns.shape[0]) +
              " columns that have missing values.")
        return mis_val_table_ren_columns

missing_values= missing_values_table(city_day)
missing_values.style.background_gradient(cmap='Reds')
# Out:
# Your selected dataframe has 16 columns.
# There are 14 columns that have missing values.
# <style  type="text/css" >
#     #T_e59022ba_e3bb_11ea_9200_d183f30106cfrow0_col0 {
#             background-color:  #67000d;
#             color:  #f1f1f1;
#         }    #T_e59022ba_e3bb_11ea_9200_d183f30106cfrow0_col1 {
#             background-color:  #67000d;
#             color:  #f1f1f1;
#         }    #T_e59022ba_e3bb_11ea_9200_d183f30106cfrow1_col0 {
#             background-color:  #f5523a;
#             color:  #000000;
#         }    #T_e59022ba_e3bb_11ea_9200_d183f30106cfrow1_col1 {
#             background-color:  #f5523a;
#             color:  #000000;
#         }    #T_e59022ba_e3bb_11ea_9200_d183f30106cfrow2_col0 {
#             background-color:  #fa6547;
#             color:  #000000;
#         }    #T_e59022ba_e3bb_11ea_9200_d183f30106cfrow2_col1 {
#             background-color:  #f96346;
#             color:  #000000;
#         }    #T_e59022ba_e3bb_11ea_9200_d183f30106cfrow3_col0 {
#             background-color:  #fc9373;
#             color:  #000000;
#         }    #T_e59022ba_e3bb_11ea_9200_d183f30106cfrow3_col1 {
#             background-color:  #fc9373;
#             color:  #000000;
#         }    #T_e59022ba_e3bb_11ea_9200_d183f30106cfrow4_col0 {
#             background-color:  #fcc4ad;
#             color:  #000000;
#         }    #T_e59022ba_e3bb_11ea_9200_d183f30106cfrow4_col1 {
#             background-color:  #fcc4ad;
#             color:  #000000;
#         }    #T_e59022ba_e3bb_11ea_9200_d183f30106cfrow5_col0 {
#             background-color:  #fdd5c4;
#             color:  #000000;
#         }    #T_e59022ba_e3bb_11ea_9200_d183f30106cfrow5_col1 {
#             background-color:  #fdd5c4;
#             color:  #000000;
#         }    #T_e59022ba_e3bb_11ea_9200_d183f30106cfrow6_col0 {
#             background-color:  #fdd5c4;
#             color:  #000000;
#         }    #T_e59022ba_e3bb_11ea_9200_d183f30106cfrow6_col1 {
#             background-color:  #fdd5c4;
#             color:  #000000;
#         }    #T_e59022ba_e3bb_11ea_9200_d183f30106cfrow7_col0 {
#             background-color:  #fdd7c6;
#             color:  #000000;
#         }    #T_e59022ba_e3bb_11ea_9200_d183f30106cfrow7_col1 {
#             background-color:  #fdd7c6;
#             color:  #000000;
#         }    #T_e59022ba_e3bb_11ea_9200_d183f30106cfrow8_col0 {
#             background-color:  #fedfd0;
#             color:  #000000;
#         }    #T_e59022ba_e3bb_11ea_9200_d183f30106cfrow8_col1 {
#             background-color:  #fedfd0;
#             color:  #000000;
#         }    #T_e59022ba_e3bb_11ea_9200_d183f30106cfrow9_col0 {
#             background-color:  #fee1d3;
#             color:  #000000;
#         }    #T_e59022ba_e3bb_11ea_9200_d183f30106cfrow9_col1 {
#             background-color:  #fee1d3;
#             color:  #000000;
#         }    #T_e59022ba_e3bb_11ea_9200_d183f30106cfrow10_col0 {
#             background-color:  #fee3d6;
#             color:  #000000;
#         }    #T_e59022ba_e3bb_11ea_9200_d183f30106cfrow10_col1 {
#             background-color:  #fee3d6;
#             color:  #000000;
#         }    #T_e59022ba_e3bb_11ea_9200_d183f30106cfrow11_col0 {
#             background-color:  #fee5d9;
#             color:  #000000;
#         }    #T_e59022ba_e3bb_11ea_9200_d183f30106cfrow11_col1 {
#             background-color:  #fee5d9;
#             color:  #000000;
#         }    #T_e59022ba_e3bb_11ea_9200_d183f30106cfrow12_col0 {
#             background-color:  #fee5d9;
#             color:  #000000;
#         }    #T_e59022ba_e3bb_11ea_9200_d183f30106cfrow12_col1 {
#             background-color:  #fee5d9;
#             color:  #000000;
#         }    #T_e59022ba_e3bb_11ea_9200_d183f30106cfrow13_col0 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_e59022ba_e3bb_11ea_9200_d183f30106cfrow13_col1 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }</style><table id="T_e59022ba_e3bb_11ea_9200_d183f30106cf" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Missing Values</th>        <th class="col_heading level0 col1" >% of Total Values</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_e59022ba_e3bb_11ea_9200_d183f30106cflevel0_row0" class="row_heading level0 row0" >Xylene</th>
#                         <td id="T_e59022ba_e3bb_11ea_9200_d183f30106cfrow0_col0" class="data row0 col0" >18109</td>
#                         <td id="T_e59022ba_e3bb_11ea_9200_d183f30106cfrow0_col1" class="data row0 col1" >61.3</td>
#             </tr>
#             <tr>
#                         <th id="T_e59022ba_e3bb_11ea_9200_d183f30106cflevel0_row1" class="row_heading level0 row1" >PM10</th>
#                         <td id="T_e59022ba_e3bb_11ea_9200_d183f30106cfrow1_col0" class="data row1 col0" >11140</td>
#                         <td id="T_e59022ba_e3bb_11ea_9200_d183f30106cfrow1_col1" class="data row1 col1" >37.7</td>
#             </tr>
#             <tr>
#                         <th id="T_e59022ba_e3bb_11ea_9200_d183f30106cflevel0_row2" class="row_heading level0 row2" >NH3</th>
#                         <td id="T_e59022ba_e3bb_11ea_9200_d183f30106cfrow2_col0" class="data row2 col0" >10328</td>
#                         <td id="T_e59022ba_e3bb_11ea_9200_d183f30106cfrow2_col1" class="data row2 col1" >35</td>
#             </tr>
#             <tr>
#                         <th id="T_e59022ba_e3bb_11ea_9200_d183f30106cflevel0_row3" class="row_heading level0 row3" >Toluene</th>
#                         <td id="T_e59022ba_e3bb_11ea_9200_d183f30106cfrow3_col0" class="data row3 col0" >8041</td>
#                         <td id="T_e59022ba_e3bb_11ea_9200_d183f30106cfrow3_col1" class="data row3 col1" >27.2</td>
#             </tr>
#             <tr>
#                         <th id="T_e59022ba_e3bb_11ea_9200_d183f30106cflevel0_row4" class="row_heading level0 row4" >Benzene</th>
#                         <td id="T_e59022ba_e3bb_11ea_9200_d183f30106cfrow4_col0" class="data row4 col0" >5623</td>
#                         <td id="T_e59022ba_e3bb_11ea_9200_d183f30106cfrow4_col1" class="data row4 col1" >19</td>
#             </tr>
#             <tr>
#                         <th id="T_e59022ba_e3bb_11ea_9200_d183f30106cflevel0_row5" class="row_heading level0 row5" >AQI</th>
#                         <td id="T_e59022ba_e3bb_11ea_9200_d183f30106cfrow5_col0" class="data row5 col0" >4681</td>
#                         <td id="T_e59022ba_e3bb_11ea_9200_d183f30106cfrow5_col1" class="data row5 col1" >15.9</td>
#             </tr>
#             <tr>
#                         <th id="T_e59022ba_e3bb_11ea_9200_d183f30106cflevel0_row6" class="row_heading level0 row6" >AQI_Bucket</th>
#                         <td id="T_e59022ba_e3bb_11ea_9200_d183f30106cfrow6_col0" class="data row6 col0" >4681</td>
#                         <td id="T_e59022ba_e3bb_11ea_9200_d183f30106cfrow6_col1" class="data row6 col1" >15.9</td>
#             </tr>
#             <tr>
#                         <th id="T_e59022ba_e3bb_11ea_9200_d183f30106cflevel0_row7" class="row_heading level0 row7" >PM2.5</th>
#                         <td id="T_e59022ba_e3bb_11ea_9200_d183f30106cfrow7_col0" class="data row7 col0" >4598</td>
#                         <td id="T_e59022ba_e3bb_11ea_9200_d183f30106cfrow7_col1" class="data row7 col1" >15.6</td>
#             </tr>
#             <tr>
#                         <th id="T_e59022ba_e3bb_11ea_9200_d183f30106cflevel0_row8" class="row_heading level0 row8" >NOx</th>
#                         <td id="T_e59022ba_e3bb_11ea_9200_d183f30106cfrow8_col0" class="data row8 col0" >4185</td>
#                         <td id="T_e59022ba_e3bb_11ea_9200_d183f30106cfrow8_col1" class="data row8 col1" >14.2</td>
#             </tr>
#             <tr>
#                         <th id="T_e59022ba_e3bb_11ea_9200_d183f30106cflevel0_row9" class="row_heading level0 row9" >O3</th>
#                         <td id="T_e59022ba_e3bb_11ea_9200_d183f30106cfrow9_col0" class="data row9 col0" >4022</td>
#                         <td id="T_e59022ba_e3bb_11ea_9200_d183f30106cfrow9_col1" class="data row9 col1" >13.6</td>
#             </tr>
#             <tr>
#                         <th id="

# %%
cities = city_day['City'].value_counts()
print(f'Total number of cities in the dataset : {len(cities)}')
print(cities.index)
# Out:
# Total number of cities in the dataset : 26
# Index(['Delhi', 'Lucknow', 'Ahmedabad', 'Bengaluru', 'Chennai', 'Mumbai',
#        'Hyderabad', 'Patna', 'Gurugram', 'Visakhapatnam', 'Amritsar',
#        'Jorapokhar', 'Jaipur', 'Thiruvananthapuram', 'Amaravati',
#        'Brajrajnagar', 'Talcher', 'Kolkata', 'Guwahati', 'Coimbatore',
#        'Shillong', 'Chandigarh', 'Bhopal', 'Kochi', 'Ernakulam', 'Aizawl'],
#       dtype='object')

# %%
city_day['Date'] = pd.to_datetime(city_day['Date'])

# %%
print(f"The available data is between {city_day['Date'].min()} and {city_day['Date'].max()}")
# Out:
# The available data is between 2015-01-01 00:00:00 and 2020-07-01 00:00:00

# %%
city_day['BTX'] = city_day['Benzene']+city_day['Toluene']+city_day['Xylene']
city_day.drop(['Benzene','Toluene','Xylene'],axis=1);

# %%
city_day['Particulate_Matter'] = city_day['PM2.5']+city_day['PM10']

# %%
pollutants = ['PM2.5','PM10','NO2', 'CO', 'SO2','O3', 'BTX']

# %%
city_day.set_index('Date',inplace=True)
axes = city_day[pollutants].plot(marker='.', alpha=0.5, linestyle='None', figsize=(16, 20), subplots=True)
for ax in axes:
    
    ax.set_xlabel('Years')
    ax.set_ylabel('ug / m3')

# %%
def max_polluted_city(pollutant):
    x1 = city_day[[pollutant,'City']].groupby(["City"]).mean().sort_values(by=pollutant,ascending=False).reset_index()
    x1[pollutant] = round(x1[pollutant],2)
    return x1[:10].style.background_gradient(cmap='OrRd')

# %%
from IPython.display import display_html
def display_side_by_side(*args):
    html_str=''
    for df in args:
        html_str+=df.render()
    display_html(html_str.replace('table','table style="display:inline"'),raw=True)

# %%
pm2_5 = max_polluted_city('PM2.5')
pm10 = max_polluted_city('PM10')
no2 = max_polluted_city('NO2')
so2 = max_polluted_city('SO2')
co = max_polluted_city('CO')
btx = max_polluted_city('BTX')


display_side_by_side(pm2_5,pm10,no2,so2,co,btx)
# Out:
# <style  type="text/css" >
#     #T_f19ef67a_e3bb_11ea_8e73_d183f30106cfrow0_col1 {
#             background-color:  #7f0000;
#             color:  #f1f1f1;
#         }    #T_f19ef67a_e3bb_11ea_8e73_d183f30106cfrow1_col1 {
#             background-color:  #a80000;
#             color:  #f1f1f1;
#         }    #T_f19ef67a_e3bb_11ea_8e73_d183f30106cfrow2_col1 {
#             background-color:  #a90000;
#             color:  #f1f1f1;
#         }    #T_f19ef67a_e3bb_11ea_8e73_d183f30106cfrow3_col1 {
#             background-color:  #ce2417;
#             color:  #f1f1f1;
#         }    #T_f19ef67a_e3bb_11ea_8e73_d183f30106cfrow4_col1 {
#             background-color:  #feebcf;
#             color:  #000000;
#         }    #T_f19ef67a_e3bb_11ea_8e73_d183f30106cfrow5_col1 {
#             background-color:  #fff1de;
#             color:  #000000;
#         }    #T_f19ef67a_e3bb_11ea_8e73_d183f30106cfrow6_col1 {
#             background-color:  #fff2e0;
#             color:  #000000;
#         }    #T_f19ef67a_e3bb_11ea_8e73_d183f30106cfrow7_col1 {
#             background-color:  #fff2e1;
#             color:  #000000;
#         }    #T_f19ef67a_e3bb_11ea_8e73_d183f30106cfrow8_col1 {
#             background-color:  #fff3e2;
#             color:  #000000;
#         }    #T_f19ef67a_e3bb_11ea_8e73_d183f30106cfrow9_col1 {
#             background-color:  #fff7ec;
#             color:  #000000;
#         }</style><table style="display:inline" id="T_f19ef67a_e3bb_11ea_8e73_d183f30106cf" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >City</th>        <th class="col_heading level0 col1" >PM2.5</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_f19ef67a_e3bb_11ea_8e73_d183f30106cflevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_f19ef67a_e3bb_11ea_8e73_d183f30106cfrow0_col0" class="data row0 col0" >Patna</td>
#                         <td id="T_f19ef67a_e3bb_11ea_8e73_d183f30106cfrow0_col1" class="data row0 col1" >123.5</td>
#             </tr>
#             <tr>
#                         <th id="T_f19ef67a_e3bb_11ea_8e73_d183f30106cflevel0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_f19ef67a_e3bb_11ea_8e73_d183f30106cfrow1_col0" class="data row1 col0" >Delhi</td>
#                         <td id="T_f19ef67a_e3bb_11ea_8e73_d183f30106cfrow1_col1" class="data row1 col1" >117.2</td>
#             </tr>
#             <tr>
#                         <th id="T_f19ef67a_e3bb_11ea_8e73_d183f30106cflevel0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_f19ef67a_e3bb_11ea_8e73_d183f30106cfrow2_col0" class="data row2 col0" >Gurugram</td>
#                         <td id="T_f19ef67a_e3bb_11ea_8e73_d183f30106cfrow2_col1" class="data row2 col1" >117.1</td>
#             </tr>
#             <tr>
#                         <th id="T_f19ef67a_e3bb_11ea_8e73_d183f30106cflevel0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_f19ef67a_e3bb_11ea_8e73_d183f30106cfrow3_col0" class="data row3 col0" >Lucknow</td>
#                         <td id="T_f19ef67a_e3bb_11ea_8e73_d183f30106cfrow3_col1" class="data row3 col1" >109.71</td>
#             </tr>
#             <tr>
#                         <th id="T_f19ef67a_e3bb_11ea_8e73_d183f30106cflevel0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_f19ef67a_e3bb_11ea_8e73_d183f30106cfrow4_col0" class="data row4 col0" >Ahmedabad</td>
#                         <td id="T_f19ef67a_e3bb_11ea_8e73_d183f30106cfrow4_col1" class="data row4 col1" >67.85</td>
#             </tr>
#             <tr>
#                         <th id="T_f19ef67a_e3bb_11ea_8e73_d183f30106cflevel0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_f19ef67a_e3bb_11ea_8e73_d183f30106cfrow5_col0" class="data row5 col0" >Kolkata</td>
#                         <td id="T_f19ef67a_e3bb_11ea_8e73_d183f30106cfrow5_col1" class="data row5 col1" >64.36</td>
#             </tr>
#             <tr>
#                         <th id="T_f19ef67a_e3bb_11ea_8e73_d183f30106cflevel0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_f19ef67a_e3bb_11ea_8e73_d183f30106cfrow6_col0" class="data row6 col0" >Jorapokhar</td>
#                         <td id="T_f19ef67a_e3bb_11ea_8e73_d183f30106cfrow6_col1" class="data row6 col1" >64.23</td>
#             </tr>
#             <tr>
#                         <th id="T_f19ef67a_e3bb_11ea_8e73_d183f30106cflevel0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_f19ef67a_e3bb_11ea_8e73_d183f30106cfrow7_col0" class="data row7 col0" >Brajrajnagar</td>
#                         <td id="T_f19ef67a_e3bb_11ea_8e73_d183f30106cfrow7_col1" class="data row7 col1" >64.06</td>
#             </tr>
#             <tr>
#                         <th id="T_f19ef67a_e3bb_11ea_8e73_d183f30106cflevel0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_f19ef67a_e3bb_11ea_8e73_d183f30106cfrow8_col0" class="data row8 col0" >Guwahati</td>
#                         <td id="T_f19ef67a_e3bb_11ea_8e73_d183f30106cfrow8_col1" class="data row8 col1" >63.69</td>
#             </tr>
#             <tr>
#                         <th id="T_f19ef67a_e3bb_11ea_8e73_d183f30106cflevel0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_f19ef67a_e3bb_11ea_8e73_d183f30106cfrow9_col0" class="data row9 col0" >Talcher</td>
#                         <td id="T_f19ef67a_e3bb_11ea_8e73_d183f30106cfrow9_col1" class="data row9 col1" >61.41</td>
#             </tr>
#     </tbody></table style="display:inline"><style  type="text/css" >
#     #T_f1a0a2ee_e3bb_11ea_bb2a_d183f30106cfrow0_col1 {
#             background-color:  #7f0000;
#             color:  #f1f1f1;
#         }    #T_f1a0a2ee_e3bb_11ea_bb2a_d183f30106cfrow1_col1 {
#             background-color:  #eb5c41;
#             color:  #000000;
#         }    #T_f1a0a2ee_e3bb_11ea_bb2a_d183f30106cfrow2_col1 {
#             background-color:  #fda872;
#             color:  #000000;
#         }    #T_f1a0a2ee_e3bb_11ea_bb2a_d183f30106cfrow3_col1 {
#             background-color:  #fdcc96;
#             color:  #000000;
#         }    #T_f1a0a2ee_e3bb_11ea_bb2a_d183f30106cfrow4_col1 {
#             background-color:  #feecd1;
#             color:  #000000;
#         }    #T_f1a0a2ee_e3bb_11ea_bb2a_d183f30106cfrow5_col1 {
#             background-color:  #feefd8;
#             color:  #000000;
#         }    #T_f1a0a2ee_e3bb_11ea_bb2a_d183f30106cfrow6_col1 {
#             background-color:  #feefd9;
#             color:  #000000;
#         }    #T_f1a0a2ee_e3bb_11ea_bb2a_d183f30106cfrow7_col1 {
#             background-color:  #fff3e3;
#             color:  #000000;
#         }    #T_f1a0a2ee_e3bb_11ea_bb2a_d183f30106cfrow8_col1 {
#             background-color:  #fff6ea;
#             color:  #000000;
#         }    #T_f1a0a2ee_e3bb_11ea_bb2a_d183f30106cfrow9_col1 {
#             background-color:  #fff7ec;
#             color:  #000000;
#         }</style><table style="display:inline" id="T_f1a0a2ee_e3bb_11ea_bb2a_d183f30106cf" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >City</th>        <th class="col_heading level0 col1" >PM10</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_f1a0a2ee_e3bb_11ea_bb2a_d183f30106cflevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_f1a0a2ee_e3bb_11ea_bb2a_d183f30106cfrow0_col0" class="data row0 col0" >Delhi</td>
#                         <td id="T_f1a0a2ee_e3bb_11ea_bb2a_d183f30106cfrow0_col1" class="data row0 col1" >232.81</td>
#             </tr>
#             <tr>
#                         <th id="T_f1a0a2ee_e3bb_11ea_bb2a_d183f30106cflevel0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_f1a0a2ee_e3bb_11ea_bb2a_d183f30106cfrow1_col0" class="data row1 col0" >Gurugram</td>
#                         <td id="T_f1a0a2ee_e3bb_11ea_bb2a_d183f30106cfrow1_col1" class="data row1 col1" >191.5</td>

# %%
def trend_plot(dataframe,value):
    
    # Prepare data
    df['year'] = [d.year for d in df.Date]
    df['month'] = [d.strftime('%b') for d in df.Date]
    years = df['year'].unique()

    # Draw Plot
    fig, axes = plt.subplots(1, 2, figsize=(14,6), dpi= 80)
    sns.boxplot(x='year', y=value, data=df, ax=axes[0])
    sns.pointplot(x='month', y=value, data=df.loc[~df.year.isin([2015, 2020]), :])

    # Set Title
    axes[0].set_title('Year-wise Box Plot \n(The Trend)', fontsize=18); 
    axes[1].set_title('Month-wise Plot \n(The Seasonality)', fontsize=18)
    plt.show()

# %%
city_day.reset_index(inplace=True)
df = city_day.copy()
value='NO2'
trend_plot(df,value)

# %%
df = city_day.copy()
value='SO2'
trend_plot(df,value)

# %%
cities = ['Ahmedabad','Delhi','Bengaluru','Mumbai','Hyderabad','Chennai']

filtered_city_day = city_day[city_day['Date'] >= '2019-01-01']
AQI = filtered_city_day[filtered_city_day.City.isin(cities)][['Date','City','AQI','AQI_Bucket']]
AQI.head()
# Out:
#            Date       City     AQI AQI_Bucket
# 1461 2019-01-01  Ahmedabad  1474.0     Severe
# 1462 2019-01-02  Ahmedabad  1246.0     Severe
# 1463 2019-01-03  Ahmedabad  1719.0     Severe
# 1464 2019-01-04  Ahmedabad  1264.0     Severe
# 1465 2019-01-05  Ahmedabad  1127.0     Severe

# %%
AQI_pivot = AQI.pivot(index='Date', columns='City', values='AQI')
AQI_pivot.fillna(method='bfill',inplace=True)
AQI_beforeLockdown = AQI_pivot['2020-01-01':'2020-03-25']
AQI_afterLockdown = AQI_pivot['2020-03-26':'2020-05-01']

# %%
print(AQI_beforeLockdown.mean())
print(AQI_afterLockdown.mean())
# Out:
# City
# Ahmedabad    383.776471
# Bengaluru     96.023529
# Chennai       80.317647
# Delhi        246.305882
# Hyderabad     94.435294
# Mumbai       148.776471
# dtype: float64
# City
# Ahmedabad    127.810811
# Bengaluru     68.486486
# Chennai       62.351351
# Delhi        107.270270
# Hyderabad     65.567568
# Mumbai        73.891892
# dtype: float64

# %%
city_day
# Out:
#                 City        Date  PM2.5   PM10     NO    NO2    NOx    NH3  \
# 0          Ahmedabad  2015-01-01    NaN    NaN   0.92  18.22  17.15    NaN
# 1          Ahmedabad  2015-01-02    NaN    NaN   0.97  15.69  16.46    NaN
# 2          Ahmedabad  2015-01-03    NaN    NaN  17.40  19.30  29.70    NaN
# 3          Ahmedabad  2015-01-04    NaN    NaN   1.70  18.48  17.97    NaN
# 4          Ahmedabad  2015-01-05    NaN    NaN  22.10  21.42  37.76    NaN
# ...              ...         ...    ...    ...    ...    ...    ...    ...
# 29526  Visakhapatnam  2020-06-27  15.02  50.94   7.68  25.06  19.54  12.47
# 29527  Visakhapatnam  2020-06-28  24.38  74.09   3.42  26.06  16.53  11.99
# 29528  Visakhapatnam  2020-06-29  22.91  65.73   3.45  29.53  18.33  10.71
# 29529  Visakhapatnam  2020-06-30  16.64  49.97   4.05  29.26  18.80  10.03
# 29530  Visakhapatnam  2020-07-01  15.00  66.00   0.40  26.85  14.05   5.20
#
#           CO    SO2      O3  Benzene  Toluene  Xylene   AQI    AQI_Bucket
# 0       0.92  27.64  133.36     0.00     0.02    0.00   NaN           NaN
# 1       0.97  24.55   34.06     3.68     5.50    3.77   NaN           NaN
# 2      17.40  29.07   30.70     6.80    16.40    2.25   NaN           NaN
# 3       1.70  18.59   36.08     4.43    10.14    1.00   NaN           NaN
# 4      22.10  39.33   39.31     7.01    18.89    2.78   NaN           NaN
# ...      ...    ...     ...      ...      ...     ...   ...           ...
# 29526   0.47   8.55   23.30     2.24    12.07    0.73  41.0          Good
# 29527   0.52  12.72   30.14     0.74     2.21    0.38  70.0  Satisfactory
# 29528   0.48   8.42   30.96     0.01     0.01    0.00  68.0  Satisfactory
# 29529   0.52   9.84   28.30     0.00     0.00    0.00  54.0  Satisfactory
# 29530   0.59   2.10   17.05      NaN      NaN     NaN  50.0          Good
#
# [29531 rows x 16 columns]
